# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
image=cv2.imread('/image1.jpg')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=522x340 at 0x7F94B608F4D0>

# %%
#grey scale image
grey_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(grey_image)
# Out:
# <PIL.Image.Image image mode=L size=522x340 at 0x7F94B5F80CD0>

# %%
#inverted scale image
inverted_image = cv2.bitwise_not(grey_image)  
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=522x340 at 0x7F94B5F89D50>

# %%
#image smoothing
image_smoothing = cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)
cv2_imshow(image_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=522x340 at 0x7F94B5F8B850>

# %%
#pencil sketch
def pencil_sketch(x, y):
    return cv2.divide(x, 255 - y, scale=256)
pencil_sketch=pencil_sketch(grey_image,image_smoothing)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=522x340 at 0x7F94B5F89790>

# %%
cv2_imshow(image)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=522x340 at 0x7F94B5F757D0>
# <PIL.Image.Image image mode=L size=522x340 at 0x7F94B5F75710>
